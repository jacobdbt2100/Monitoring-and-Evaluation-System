# %% [markdown]
# ## Import Required Library

# %%
import pandas as pd

# %% [markdown]
# ## Load Raw Dataset

# %%
df = pd.read_csv("C:/Users/HP PC/Documents/jacob_git_projects/Monitoring-and-Evaluation-System/dataset/01_raw/farm_monitoring_visit_raw.csv")

print(df.shape)

df.head()
# Out:
# (2012, 24)
#    number                                formid  \
# 0       0  5d708288-28da-4a56-a8f5-d0eef8cce9e6
# 1       1  24abb0d5-803f-4542-95da-8ef447c99f8c
# 2       2  4edeab17-4174-497b-b509-e15f6f6bd616
# 3       3  f1faa20a-1e7c-44d6-aab5-22a1c04a6284
# 4       4  1530e603-e83c-4eb5-8b89-fa32eb9b902f
#
#   form.section_1_visit_information.visit_date  \
# 0                                  2026-03-28
# 1                                  2026-01-28
# 2                                  2026-01-27
# 3                                  2026-02-15
# 4                                  2026-03-26
#
#   form.section_1_visit_information.crop_stage  \
# 0                                  harvesting
# 1                            land_preparation
# 2                           vegetative_growth
# 3                                    planting
# 4                                  harvesting
#
#   form.section_1_visit_information.crops_observed_during_this_visit  \
# ...

# %% [markdown]
# ## Data Validation Checks

# %%
print("Dataset Shape")
print(df.shape)

print("\nDuplicate Rows")
print(df.duplicated().sum())

print("\nMissing Values")
print(df.isna().sum())

print("\nData Types")
print(df.dtypes)
# Out:
# Dataset Shape
# (2012, 24)
#
# Duplicate Rows
# 0
#
# Missing Values
# number                                                                                                       0
# formid                                                                                                       0
# form.section_1_visit_information.visit_date                                                                  0
# form.section_1_visit_information.crop_stage                                                                  0
# form.section_1_visit_information.crops_observed_during_this_visit                                            0
# form.section_1_visit_information.select_crop_condition.crop_condition_maize                                  0
# form.section_1_visit_information.select_crop_condition.crop_condition_rice                                   0
# form.section_1_visit_information.select_crop_condition.crop_condition_groundnuts                             0
# ...

# %% [markdown]
# ## Export Clean Dataset

# %%
# ------------------------------------------------------------
# No cleaning is required for this dataset.
# It has passed the validation checks.
# ------------------------------------------------------------

df.to_csv("C:/Users/HP PC/Documents/jacob_git_projects/Monitoring-and-Evaluation-System/dataset/02_cleaned/farm_monitoring_visit_clean.csv",
          index=False)

print("Farm Monitoring dataset exported successfully.")
# Out:
# Farm Monitoring dataset exported successfully.
