# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Raw Dataset

# %%
df = pd.read_csv("C:/Users/HP PC/Documents/jacob_git_projects/Monitoring-and-Evaluation-System/dataset/01_raw/input_distribution_raw.csv")

print(df.shape)

df.head()
# Out:
# (834, 19)
#    number                                formid form.distribution_date  \
# 0       0  1fe3638f-09d9-4959-9e16-fc4fa26399a5             2026-03-23
# 1       1  1fc17411-f823-4850-aa61-c7eefd84027d             2026-04-06
# 2       2  eb65cb9f-d00e-4b79-b8a6-dfe5cd9b53c8             2026-02-14
# 3       3  44f69c19-b8ff-42ec-acb7-cd2ffbbdd6dc             2026-04-22
# 4       4  99ca4e4a-7097-451b-bc14-e85fb669b480             2026-07-02
#
#   form.distribution_location                      form.input_type  \
# 0           Extension Office            groundnut_seed fertilizer
# 1             Primary School                           fertilizer
# 2             Primary School                            rice_seed
# 3             Primary School                       groundnut_seed
# 4  Farmer Cooperative Centre  maize_seed groundnut_seed rice_seed
#
#   form.quantity_of_inputs_distributed.maize_seed_kg  \
# 0                                               ---
# 1                                               ---
# 2                                               ---
# 3                                               ---
# 4                                               8.3
#
#   form.quantity_of_inputs_distributed.rice_seed_kg  \
# 0                                              ---
# 1                                              ---
# 2                                              2.3
# 3                                              ---
# 4                                              8.5
#
#   form.quantity_of_inputs_distributed.groundnut_seed_kg  \
# 0                                                8.0
# 1                                                ---
# 2                                                ---
# 3                                                5.2
# 4                                                7.6
#
#   form.quantity_of_inputs_distributed.fertilizer_kg  \
# 0                                              73.6
# 1                                              90.2
# 2                                               ---
# 3                                               ---
# 4                                               ---
#
#   form.quantity_of_inputs_distributed.goats_count  \
# 0                                             ---
# 1                                             ---
# 2                                             ---
# 3                                             ---
# 4                                             ---
#
#   form.quantity_of_inputs_distributed.rabbits_count  \
# 0                                               ---
# 1                                               ---
# 2                                               ---
# 3                                               ---
# 4                                               ---
#
#                             form.recipient_signature  \
# 0  https://www.commcarehq.org/a/commcare-learn-ah...
# 1  https://www.commcarehq.org/a/commcare-learn-ah...
# 2  https://www.commcarehq.org/a/commcare-learn-ah...
# 3  https://www.commcarehq.org/a/commcare-learn-ah...
# 4  https://www.commcarehq.org/a/commcare-learn-ah...
#
#                      form.case.@case_id       completed_time  \
# 0  b444a62e-13c0-4ccd-8ec2-838bb2dfe5bd  2026-03-23 13:27:00
# 1  12f1f5af-5256-4e18-96cf-f7a1dac16e7d  2026-04-06 14:28:00
# 2  0b061fab-6c5b-44bb-90cf-6f440d76f65d  2026-02-14 11:33:00
# 3  e0bd8266-2f5c-49e1-bcce-1dc843a1c529  2026-04-22 14:53:00
# 4  f6d3f342-1621-49ae-826b-6d3a9cfcec86  2026-07-02 14:09:00
#
#           started_time   username          received_on  \
# 0  2026-03-23 13:19:00  tester_05  2026-03-23 13:27:05
# 1  2026-04-06 14:25:00  tester_04  2026-04-06 14:28:08
# 2  2026-02-14 11:30:00  tester_03  2026-02-14 11:33:11
# 3  2026-04-22 14:46:00  tester_05  2026-04-22 14:53:10
# 4  2026-07-02 14:04:00  tester_06  2026-07-02 14:09:13
#
#                                            form_link    hq_user
# 0  https://www.commcarehq.org/a/commcare-learn-ah...  tester_05
# 1  https://www.commcarehq.org/a/commcare-learn-ah...  tester_04
# 2  https://www.commcarehq.org/a/commcare-learn-ah...  tester_03
# 3  https://www.commcarehq.org/a/commcare-learn-ah...  tester_05
# 4  https://www.commcarehq.org/a/commcare-learn-ah...  tester_06

# %%
# ------------------------------------------------------------
# Replace CommCare placeholder values with missing values
# ------------------------------------------------------------
# CommCare uses "---" where a question was not applicable.
# Replace these placeholders with blank (NaN) values so that
# numeric, date, and boolean fields can be imported into
# PostgreSQL without data type errors.
# ------------------------------------------------------------

df.replace("---", np.nan, inplace=True)

# %% [markdown]
# ## Data Validation Checks

# %%
print("Dataset Shape")
print(df.shape)

print("\nDuplicate Rows")
print(df.duplicated().sum())

print("\nMissing Values")
print(df.isna().sum())

print("\nData Types")
print(df.dtypes)
# Out:
# Dataset Shape
# (834, 19)
#
# Duplicate Rows
# 0
#
# Missing Values
# number                                                     0
# formid                                                     0
# form.distribution_date                                     0
# form.distribution_location                                 0
# form.input_type                                            0
# form.quantity_of_inputs_distributed.maize_seed_kg        465
# form.quantity_of_inputs_distributed.rice_seed_kg         474
# form.quantity_of_inputs_distributed.groundnut_seed_kg    455
# form.quantity_of_inputs_distributed.fertilizer_kg        272
# form.quantity_of_inputs_distributed.goats_count          604
# form.quantity_of_inputs_distributed.rabbits_count        721
# form.recipient_signature                                   0
# form.case.@case_id                                         0
# completed_time                                             0
# started_time                                               0
# username                                                   0
# received_on                                                0
# form_link                                                  0
# hq_user                                                    0
# dtype: int64
#
# Data Types
# number                                                    int64
# formid                                                   object
# form.distribution_date                                   object
# form.distribution_location                               object
# form.input_type                                          object
# form.quantity_of_inputs_distributed.maize_seed_kg        object
# form.quantity_of_inputs_distributed.rice_seed_kg         object
# form.quantity_of_inputs_distributed.groundnut_seed_kg    object
# form.quantity_of_inputs_distributed.fertilizer_kg        object
# form.quantity_of_inputs_distributed.goats_count          object
# form.quantity_of_inputs_distributed.rabbits_count        object
# form.recipient_signature                                 object
# form.case.@case_id                                       object
# completed_time                                           object
# started_time                                             object
# username                                                 object
# received_on                                              object
# form_link                                                object
# hq_user                                                  object
# dtype: object

# %% [markdown]
# ## Export Clean Dataset

# %%
# ------------------------------------------------------------
# No cleaning is required for this dataset.
# It has passed the validation checks.
# ------------------------------------------------------------

df.to_csv("C:/Users/HP PC/Documents/jacob_git_projects/Monitoring-and-Evaluation-System/dataset/02_cleaned/input_distribution_clean.csv",
          index=False)

print("Input Distribution dataset exported successfully.")
# Out:
# Input Distribution dataset exported successfully.
